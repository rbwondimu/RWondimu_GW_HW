# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x11dcc2e80>,
#   <matplotlib.axis.XTick at 0x11dcc27b8>,
#   <matplotlib.axis.XTick at 0x11df66d68>,
#   <matplotlib.axis.XTick at 0x11dff4b70>,
#   <matplotlib.axis.XTick at 0x11e0070f0>,
#   <matplotlib.axis.XTick at 0x11e0075f8>,
#   <matplotlib.axis.XTick at 0x11e007b70>,
#   <matplotlib.axis.XTick at 0x11e009160>,
#   <matplotlib.axis.XTick at 0x11e0096a0>,
#   <matplotlib.axis.XTick at 0x11e009c18>,
#   <matplotlib.axis.XTick at 0x11e009518>,
#   <matplotlib.axis.XTick at 0x11e007550>,
#   <matplotlib.axis.XTick at 0x11e013390>,
#   <matplotlib.axis.XTick at 0x11e013908>,
#   <matplotlib.axis.XTick at 0x11e013e80>,
#   <matplotlib.axis.XTick at 0x11e015438>,
#   <matplotlib.axis.XTick at 0x11e0159b0>,
#   <matplotlib.axis.XTick at 0x11e015f28>,
#   <matplotlib.axis.XTick at 0x11e0224e0>,
#   <matplotlib.axis.XTick at 0x11e0154e0>,
#   <matplotlib.axis.XTick at 0x11e0138d0>,
#   <matplotlib.axis.XTick at 0x11e022cc0>,
#   <matplotlib.axis.XTick at 0x11e0290f0>,
#   <matplotlib.axis.XTick at 0x11e0295f8>,
#   <matplotlib.axis.XTick at 0x11e029b70>,
#   <matplotlib.axis.XTick at 0x11e030160>,
#   <matplotlib.axis.XTick at 0x11e0306a0>,
#   <matplotlib.axis.XTick at 0x11e030c18>,
#   <matplotlib.axis.XTick at 0x11e0381d0>,
#   <matplotlib.axis.XTick at 0x11e030748>,
#   <matplotlib.axis.XTick at 0x11e013438>,
#   <matplotlib.axis.XTick at 0x11e038668>,
#   <matplotlib.axis.XTick at 0x11e038be0>,
#   <matplotlib.axis.XTick at 0x11e03f198>,
#   <matplotlib.axis.XTick at 0x11e03f710>,
#   <matplotlib.axis.XTick at 0x11e03fc88>,
#   <matplotlib.axis.XTick at 0x11e046240>,
#   <matplotlib.axis.XTick at 0x11e0467b8>,
#   <matplotlib.axis.XTick at 0x11e03f240>,
#   <matplotlib.axis.XTick at 0x11e038630>,
#   <matplotlib.axis.XTick at 0x11e046f60>,
#   <matplotlib.axis.XTick at 0x11e04d278>,
#   <matplotlib.axis.XTick at 0x11e04d7f0>,
#   <matplotlib.axis.XTick at 0x11e04dd68>,
#   <matplotlib.axis.XTick at 0x11e053320>,
#   <matplotlib.axis.XTick at 0x11e053898>,
#   <matplotlib.axis.XTick at 0x11e053e10>,
#   <matplotlib.axis.XTick at 0x11e05d3c8>,
#   <matplotlib.axis.XTick at 0x11e053978>,
#   <matplotlib.axis.XTick at 0x11e04d898>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()
